# %%
#Preprocessing Data

# %%
import pandas as pd #Importing pandas library
import numpy as np #Importing numpy library
import matplotlib.pyplot as plt #Importing Matplotlib library's "pyplot"
import seaborn as sns  # Imorting Seaborn library
import os



data = pd.read_csv("Breast_Cancer_Classification.csv")
data
# Out:
#            id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         21.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
del data['id']
data
# Out:
#     diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         21.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#Converting the diagnosis values from strings to 1s or 0s) 
data = pd.get_dummies(data,drop_first=True)
data
# Out:
#      Radius_mean  Texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         21.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(data.corr( ), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Removing Highly Correlated Data
data.drop(["perimeter_mean","perimeter_se","perimeter_worst"],axis="columns",inplace=True) 
data.drop(["Radius_mean","radius_se","radius_worst"],axis="columns",inplace=True)
data.drop(["symmetry_se","texture_se","smoothness_se","fractal_dimension_se"],axis="columns",inplace=True)
data.drop("fractal_dimension_mean",axis="columns",inplace=True) 
data.drop("Texture_mean",axis="columns",inplace=True)
data.drop(["area_mean","compactness_worst"],axis="columns",inplace=True)

# %%
plt.figure(figsize=(25,20))
sns.heatmap(data=data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.columns.unique()
# Out:
# Index(['smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'area_se', 'compactness_se',
#        'concavity_se', 'concave points_se', 'texture_worst', 'area_worst',
#        'smoothness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'diagnosis_M'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

X = data.drop(["diagnosis_M"],axis="columns")
Scaler = StandardScaler()
X = Scaler.fit_transform(X)
y = data["diagnosis_M"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 42)

# %%
lst_num_column = []
for column in data.columns:
    if (data[column].dtype == np.float64):## only plotting non categorical features.
        lst_num_column.append(column)
#----------------------------------------------------------------------------------------
rows = 3
columns = 5
count = 0
fig, axs = plt.subplots(rows, columns, figsize=(25,12))
for i in range(rows):
    for j in range(columns):
        sns.histplot(ax= axs[i, j], data=data, x=lst_num_column[count], kde=True)
        count += 1

# %% [markdown]
# # Training Models

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
 
import warnings
warnings.filterwarnings('ignore')

clf = MLPClassifier(random_state=42, max_iter=300).fit(X_train, y_train)

print(clf.score(X_train,y_train))
y_pred = clf.predict(X_test)
# Out:
# 0.9929577464788732

# %%
print(clf.score(X_test,y_test))
# Out:
# 0.972027972027972

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)

print(accuracy_score(y_test, y_pred))

sns.heatmap(cm, annot=True).set(xlabel='Predicted', ylabel='True')
# Out:
# 0.972027972027972
# [Text(0.5, 15.0, 'Predicted'), Text(33.0, 0.5, 'True')]

# %% [markdown]
# ## Gradient Boosted Trees

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0).fit(X_train, y_train)
 
print(gbc.score(X_train,y_train))
Y_pred = gbc.predict(X_test)
# Out:
# 1.0

# %%
print(gbc.score(X_test,y_test))
# Out:
# 0.9790209790209791

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm1 = confusion_matrix(y_test, Y_pred)

print(accuracy_score(y_test, Y_pred))

sns.heatmap(cm1, annot=True).set(xlabel='Predicted', ylabel='True')
# Out:
# 0.9790209790209791
# [Text(0.5, 15.0, 'Predicted'), Text(33.0, 0.5, 'True')]

# %% [markdown]
# ## Linear Ridge Classification (Penalized model)

# %%
from sklearn.linear_model import RidgeClassifier
rgclf = RidgeClassifier(max_iter=1000, class_weight='balanced').fit(X_train, y_train)


Y_Pred = rgclf.predict(X_test)

print(rgclf.score(X_train, y_train))
# Out:
# 0.9671361502347418

# %%
print(rgclf.score(X_test,y_test))
# Out:
# 0.951048951048951

# %%
cm2 = confusion_matrix(y_test, Y_Pred)

print(accuracy_score(y_test, Y_Pred))


sns.heatmap(cm2, annot=True).set(xlabel='Predicted', ylabel='True')
# Out:
# 0.951048951048951
# [Text(0.5, 15.0, 'Predicted'), Text(33.0, 0.5, 'True')]
